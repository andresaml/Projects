# %%
# Import Libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import pandas as pd

# %%
# Connect to website

url = 'https://www.amazon.com/Hanes-ComfortWash-Garment-Sweatshirt-Cypress/dp/B07JZNQ44H/ref=sr_1_5?dchild=1&keywords=hoodies&qid=1631030405&sr=8-5&th=1&psc=1'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(url, headers = headers)

soup1 = BeautifulSoup(page.content, 'html.parser')

# prettify just makes things look better
soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id="priceblock_ourprice").get_text()

size = soup2.find(id='dropdown_selected_size_name').get_text()

color = soup2.find(id='variation_color_name').get_text()

print(title)
print(price)
print(size)
print(color)
# Out:
#                    Hanes Men's Comfortwash Garment Dyed Hoodie Sweatshirt
#
#
#                     $29.50
#
#
#
#
#
#                         Medium
#
#
#
#
#
#
#
#
#
#                     Color:
#
#
#                     Cypress Green

# %%
price.strip() #this takes the junk out of it
# Out:
# '$29.50'

# %%
#lets take de $ sign out of it
price = price.strip()[1:]
price
# Out:
# '29.50'

# %%
title = title.strip()
size = size.strip()
color = color.strip()[6:]

print(title)
print(price)
print(color)
print(size)
# Out:
# Hanes Men's Comfortwash Garment Dyed Hoodie Sweatshirt
# 29.50
#
#
#
#                     Cypress Green
# Medium

# %%
color = color.strip()

print(title)
print(price)
print(color)
print(size)
# Out:
# Hanes Men's Comfortwash Garment Dyed Hoodie Sweatshirt
# 29.50
# Cypress Green
# Medium

# %%
import datetime

today = datetime.date.today()

print(today)
# Out:
# 2021-09-07

# %%
import csv

header = ['Title', 'Price', 'Size', 'Color', 'Date']
data = [title, price, size, color, today]

# w means write
with open('AmazonWebScraperDataset.csv', 'w', newline = '', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df = pd.read_csv(r'C:\Users\Andres\AmazonWebScraperDataset.csv')

df.head()
# Out:
#                                                Title  Price    Size  \
# 0  Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
#
#            Color        Date
# 0  Cypress Green  2021-09-07

# %%
# Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    url = 'https://www.amazon.com/Hanes-ComfortWash-Garment-Sweatshirt-Cypress/dp/B07JZNQ44H/ref=sr_1_5?dchild=1&keywords=hoodies&qid=1631030405&sr=8-5&th=1&psc=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(url, headers = headers)

    soup1 = BeautifulSoup(page.content, 'html.parser')

    soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

    title = soup2.find(id='productTitle').get_text()

    price = soup2.find(id="priceblock_ourprice").get_text()

    size = soup2.find(id='dropdown_selected_size_name').get_text()

    color = soup2.find(id='variation_color_name').get_text()
    
    price = price.strip()[1:]
    
    title = title.strip()
    
    size = size.strip()
    
    color = color.strip()[6:]
    
    color = color.strip()
    
    import datetime

    today = datetime.date.today()

    import csv

    header = ['Title', 'Price', 'Size', 'Color', 'Date']
    data = [title, price, size, color, today]
    
    with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding = 'UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

        if(price < 30):
            send_mail()

# %%
while(True):
    check_price()
    time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-c5092fbdb4e1> in <module>
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(10)
#
# <ipython-input-68-71e9c2f87ac3> in check_price()
#      41         writer.writerow(data)
#      42
# ---> 43         if(price < 30):
#      44             send_mail()
#      45
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
df = pd.read_csv(r'C:\Users\Andres\AmazonWebScraperDataset.csv')

print(df)
# Out:
#                                                 Title  Price    Size  \
# 0   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 1   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 2   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 3   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 4   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 5   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 6   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 7   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 8   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 9   Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 10  Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 11  Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# 12  Hanes Men's Comfortwash Garment Dyed Hoodie Sw...   29.5  Medium
# ...

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',456)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('andresaml97@gmail.com', 'aamlaeh56h')
    
    subject = 'The hoodie you want is below 20$! Now is your chance to buy!'
    body = ('Andres, this is the moment we have been waiting for. Now is your chance to pick up the hoodie of your dreams!')
    
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'andresaml97@gmail.com',
        msg
        
    )
